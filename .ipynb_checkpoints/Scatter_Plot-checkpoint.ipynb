# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.arange(0,10)
y=np.arange(0,10)

# %%
plt.scatter(x,y,c='g')
plt.xlabel('X Axis')
plt.xlabel('Y Axis')
plt.title('Scatter Plot')
plt.savefig('scatterplot.png')

# %%
x=np.arange(0,10)
y=x*x

# %%
plt.scatter(x,y,c='r')
plt.xlabel('X')
plt.xlabel('Y=X^2')
plt.title('Square')
plt.plot(x,y,'r*',linestyle='dashed')
plt.savefig('Square.png')

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g--')
plt.subplot(2,2,3)
plt.plot(x,y,'bo')
plt.subplot(2,2,4)
plt.plot(x,y,'go')

# %%
a=np.arange(1,12)
b=(3*a)+5
plt.plot(a,b,c='g')
plt.xlabel('X')
plt.xlabel('Y=3X+5')
plt.title('3X+5')

plt.savefig('Equation.png')

# %%
c=np.arange(0,4*np.pi,0.1)
d=np.sin(c)
plt.plot(c,d,c='r')
plt.title('Sin Wave')
plt.savefig('SinWave.png')

# %%
x1=np.arange(0,4*np.pi,0.1)
y_sin=np.sin(x1)
y_cos=np.cos(x1)
plt.subplot(2,2,1)
plt.plot(x1,y_sin,'r')
plt.title("Sin")
plt.subplot(2,2,2)
plt.plot(x1,y_cos,'m')
plt.title("Cos")
plt.savefig('Sin_Cos.png')

# %%
x=[2,8,10]
y=[11,16,9]
x1=[3,9,11]
y1=[6,15,17]
plt.bar(x,y)
plt.bar(x1,y1,color='r')
# Out:
# <BarContainer object of 3 artists>

# %%
x=np.array([22,11,47,52,12,60,8,27,44,42])
plt.hist(x,bins=30, color='m')
plt.title("Histogram")
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
data=[np.random.normal(0,std,100)for std in range(1,4)]
plt.boxplot(data,vert=True,patch_artist=False)
plt.title('Boxplot')
plt.savefig('Boxplot.png')

# %%
label=['python','cpp','Ruby','Java',]
size=[215,15,245,210]
color=['gold','yellowgreen','lightcoral','lightskyblue']
explode=[0.4,0,0,0]
plt.pie(size,explode=explode,labels=label,colors=color)
# Out:
# ([<matplotlib.patches.Wedge at 0x1fc04fd4650>,
#   <matplotlib.patches.Wedge at 0x1fc051f3790>,
#   <matplotlib.patches.Wedge at 0x1fc03c0b010>,
#   <matplotlib.patches.Wedge at 0x1fc04fcf850>],
#  [Text(0.6623881248288015, 1.0006207933506999, 'python'),
#   Text(-0.5435623143520364, 1.0698317673430053, 'cpp'),
#   Text(-1.1949554196602563, -0.10991608173775543, 'Ruby'),
#   Text(0.6851574653936684, -0.9851696542298308, 'Java')])
